# %% [markdown]
# # Introduction to Folium

# %%
# importing Libraries
import folium

# %%
#creating world map
m = folium.Map()
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#India Mao

india1 = folium.Map(location = [20.5937,78.9629],zoom_start=4.5)
#india1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# India Map with new Tiles
india2 = folium.Map(location = [20.5937,78.9629],zoom_start=4.5,tiles='Stamen Toner')
#india2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
india3 = folium.Map(location = [20.5937,78.9629],zoom_start=4.5,tiles='Stamen Terrain')
india3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Retreving the states information (Latitudes and Longitudes)

# %%
#Installing the lxml to retreive tables from websites
conda install lxml

# %%
# importing padas for processing Data
import pandas as pd

# %%
#importing Latitudes and Longitudes
info = pd.read_html("http://www.quickgs.com/latitudinal-and-longitudinal-extents-of-india-indian-states-and-cities/")

# %%
#Converting information into DataFrame
data = pd.DataFrame(info[0])

# %%
#view Data
data
# Out:
#                 State  Latitude Longitude
# 0      Andhra Pradesh   15.91°N   79.74°E
# 1   Arunachal Pradesh   28.21°N   94.72°E
# 2               Assam   26.20°N   92.93°E
# 3               Bihar   25.09°N   85.31°E
# 4        Chhattisgarh   21.27°N   81.86°E
# 5                 Goa   15.29°N   74.12°E
# 6             Gujarat   22.25°N   71.19°E
# 7             Haryana   29.05°N   76.08°E
# 8    Himachal Pradesh   31.10°N   77.17°E
# 9     Jammu & Kashmir  33.77 °N   76.57°E
# 10          Jharkhand   23.61°N   85.27°E
# 11          Karnataka   15.31°N   75.71°E
# 12             Kerala   10.85°N   76.27°E
# 13     Madhya Pradesh   22.97°N   78.65°E
# 14        Maharashtra   19.75°N   75.71°E
# 15            Manipur   24.66°N   93.90°E
# 16          Meghalaya   25.46°N   91.36°E
# 17            Mizoram   23.16°N   92.93°E
# 18           Nagaland   26.15°N   94.56°E
# 19             Odisha   20.95°N   85.09°E
# 20             Punjab   31.14°N   75.34°E
# 21          Rajasthan   27.02°N   74.21°E
# 22             Sikkim   27.53°N   88.51°E
# 23         Tamil Nadu   11.12°N   78.65°E
# 24            Tripura   23.94°N   91.98°E
# 25        Uttarakhand   30.06°N   79.01°E
# 26      Uttar Pradesh   26.84°N   80.94°E
# 27        West Bengal   22.98°N   87.85°E

# %%
#Data cleaning Transforming Latitude and Longitude into algorithm compatible form
def data_pre(cord):
    return cord[0:5]

# %%
data['Latitude'] = data['Latitude'].apply(data_pre)

# %%
data['Longitude'] = data['Longitude'].apply(data_pre)

# %%
#Changing the data type from object to float
data['Longitude'] = data['Longitude'].astype('float')

# %%
data['Latitude'] = data['Latitude'].astype('float')

# %%
data.dtypes
# Out:
# State         object
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
data.head()
# Out:
#                State  Latitude  Longitude
# 0     Andhra Pradesh     15.91      79.74
# 1  Arunachal Pradesh     28.21      94.72
# 2              Assam     26.20      92.93
# 3              Bihar     25.09      85.31
# 4       Chhattisgarh     21.27      81.86

# %% [markdown]
# # Retreving Live Covid Cases Count all over India

# %%
#Retreving the LIVE COVID19 Statistics
info2 = pd.read_html('https://en.wikipedia.org/wiki/COVID-19_pandemic_in_India',match='COVID-19 pandemic in India by state and union territory')
len(info2)
# Out:
# 2

# %%
#Convert to DataFrame
covid19 = pd.DataFrame(info2[0])
covid19.head()
# Out:
#                                                    0  \
# 0  vte COVID-19 pandemic in India by state and un...
# 1  vte COVID-19 pandemic in India by state and un...
# 2                                              S.No.
# 3                                                  1
# 4                                                  2
#
#                                                    1  \
# 0  Map of COVID-19 cases per million population i...
# 1  vte COVID-19 pandemic in India by state and un...
# 2                              State/Union Territory
# 3                        Andaman and Nicobar Islands
# 4                                     Andhra Pradesh
#
#                                                    2  \
# 0                                                NaN
# 1  vte COVID-19 pandemic in India by state and un...
# 2                                        Total cases
# 3                                                 33
# 4                                               3679
#
#                                                    3  \
# 0                                                NaN
# 1  vte COVID-19 pandemic in India by state and un...
# 2                                             Deaths
# 3                                                  0
# 4                                                 62
#
#                                                    4  \
# 0                                                NaN
# 1  vte COVID-19 pandemic in India by state and un...
# 2                                         Recoveries
# 3                                                 33
# 4                                               2349
#
#                                                    5
# 0                                                NaN
# 1  vte COVID-19 pandemic in India by state and un...
# 2                                       Active cases
# 3                                                  0
# 4                                               1268

# %%
#Droping the first 2 rows
covid19.drop([0,1],inplace=True)
covid19.head()
# Out:
#        0                            1            2       3           4  \
# 2  S.No.        State/Union Territory  Total cases  Deaths  Recoveries
# 3      1  Andaman and Nicobar Islands           33       0          33
# 4      2               Andhra Pradesh         3679      62        2349
# 5      3            Arunachal Pradesh            4       0           1
# 6      4                        Assam      1272[a]       4         185
#
#               5
# 2  Active cases
# 3             0
# 4          1268
# 5             3
# 6          1083

# %%
#Making first row as index and droping last unwanted rows
header = list(covid19.iloc[0,:])
header[1]='State'
covid19 = covid19.iloc[1:-3,:]
covid19.columns = header

# %%
covid19.head()
# Out:
#   S.No.                        State Total cases Deaths Recoveries  \
# 3     1  Andaman and Nicobar Islands          33      0         33
# 4     2               Andhra Pradesh        3679     62       2349
# 5     3            Arunachal Pradesh           4      0          1
# 6     4                        Assam     1272[a]      4        185
# 7     5                        Bihar        3815     21       1710
#
#   Active cases
# 3            0
# 4         1268
# 5            3
# 6         1083
# 7         2084

# %%
#Making the two Datasets Compatible
state_data = list(data['State'])
covid19_state = list(covid19['State'])
missing =[]
for state in covid19_state:
    if (state not in state_data):
        missing.append(state)
missing
# Out:
# ['Andaman and Nicobar Islands',
#  'Chandigarh',
#  'Dadra and Nagar Haveli and Daman and Diu',
#  'Delhi',
#  'Jammu and Kashmir',
#  'Ladakh',
#  'Lakshadweep',
#  'Puducherry',
#  'Telangana']

# %%
#adding Rows to Data
rows = [['Andaman and Nicobar Islands',11.74,92.65],['Lakshadweep',10.56,72.64],['Puducherry',11.94,79.80],['Telangana',18.11,79.01]]
data = data.append(pd.DataFrame(rows,columns=['State','Latitude','Longitude']),ignore_index=True)

# %%
data
# Out:
#                           State  Latitude  Longitude
# 0                Andhra Pradesh     15.91      79.74
# 1             Arunachal Pradesh     28.21      94.72
# 2                         Assam     26.20      92.93
# 3                         Bihar     25.09      85.31
# 4                  Chhattisgarh     21.27      81.86
# 5                           Goa     15.29      74.12
# 6                       Gujarat     22.25      71.19
# 7                       Haryana     29.05      76.08
# 8              Himachal Pradesh     31.10      77.17
# 9               Jammu & Kashmir     33.77      76.57
# 10                    Jharkhand     23.61      85.27
# 11                    Karnataka     15.31      75.71
# 12                       Kerala     10.85      76.27
# 13               Madhya Pradesh     22.97      78.65
# 14                  Maharashtra     19.75      75.71
# 15                      Manipur     24.66      93.90
# 16                    Meghalaya     25.46      91.36
# 17                      Mizoram     23.16      92.93
# 18                     Nagaland     26.15      94.56
# 19                       Odisha     20.95      85.09
# 20                       Punjab     31.14      75.34
# 21                    Rajasthan     27.02      74.21
# 22                       Sikkim     27.53      88.51
# 23                   Tamil Nadu     11.12      78.65
# 24                      Tripura     23.94      91.98
# 25                  Uttarakhand     30.06      79.01
# 26                Uttar Pradesh     26.84      80.94
# 27                  West Bengal     22.98      87.85
# 28  Andaman and Nicobar Islands     11.74      92.65
# 29                  Lakshadweep     10.56      72.64
# 30                   Puducherry     11.94      79.80
# 31                    Telangana     18.11      79.01

# %%
covid19['S.No.'] = covid19['S.No.'].astype('int')

# %%
covid19 = covid19[(covid19['S.No.']!=6) & (covid19['S.No.']!=8) & (covid19['S.No.']!=9) & (covid19['S.No.']!=18)]

# %%
data['State']=data['State'].replace('Jammu & Kashmir','Jammu and Kashmir')

# %%
final_data = pd.merge(data, covid19, how ='inner', on ='State')
final_data.drop(['S.No.'],axis=1)
# Out:
#                           State  Latitude  Longitude Total cases Deaths  \
# 0                Andhra Pradesh     15.91      79.74        3679     62
# 1             Arunachal Pradesh     28.21      94.72           4      0
# 2                         Assam     26.20      92.93     1272[a]      4
# 3                         Bihar     25.09      85.31        3815     21
# 4                  Chhattisgarh     21.27      81.86         498      1
# 5                           Goa     15.29      74.12          70      0
# 6                       Gujarat     22.25      71.19       16779   1038
# 7                       Haryana     29.05      76.08        2091     20
# 8              Himachal Pradesh     31.10      77.17         331      5
# 9             Jammu and Kashmir     33.77      76.57        2446     28
# 10                    Jharkhand     23.61      85.27         610      5
# 11                    Karnataka     15.31      75.71        3221     51
# 12                       Kerala     10.85      76.27        1269   9[b]
# 13               Madhya Pradesh     22.97      78.65        8089    350
# 14                  Maharashtra     19.75      75.71       67655   2286
# 15                      Manipur     24.66      93.90          71      0
# 16                    Meghalaya     25.46      91.36          27      1
# 17                      Mizoram     23.16      92.93           1      0
# 18                     Nagaland     26.15      94.56          43      0
# 19                       Odisha     20.95      85.09        1948      7
# 20                       Punjab     31.14      75.34        2263     45
# 21                    Rajasthan     27.02      74.21        8831    194
# 22                       Sikkim     27.53      88.51           1      0
# 23                   Tamil Nadu     11.12      78.65       22333    173
# 24                      Tripura     23.94      91.98         313      0
# 25                  Uttarakhand     30.06      79.01         907      5
# 26                Uttar Pradesh     26.84      80.94        7823    213
# 27                  West Bengal     22.98      87.85        5501    317
# 28  Andaman and Nicobar Islands     11.74      92.65          33      0
# 29                  Lakshadweep     10.56      72.64           0      0
# 30                   Puducherry     11.94      79.80          70      0
# 31                    Telangana     18.11      79.01        2698     82
#
#    Recoveries Active cases
# 0        2349         1268
# 1           1            3
# 2         185         1083
# 3        1710         2084
# 4         115          382
# 5          42           28
# 6        9919         5822
# 7        1048         1023
# 8         120          206
# 9         927         1491
# 10        256          349
# 11       1218         1952
# 12        590          670
# 13       4842         2897
# 14      29329        36040
# 15         11           60
# 16         12           14
# 17          1            0
# 18          0           43
# 19       1126          815
# 20       1987          231
# 21       5927         2710
# 22          0            1
# 23      12757         9403
# 24        173          140
# 25        102          800
# 26       4709         2901
# 27       2157         3027
# 28         33            0
# 29          0            0
# 30         25           45
# 31       1428         1188

# %% [markdown]
# # add Markers to states

# %%
for state,lat,long,total_cases,Death,Recov,Active in zip(list(final_data['State']),list(final_data['Latitude']),list(final_data['Longitude']),list(final_data['Total cases']),list(final_data['Deaths']),list(final_data['Recoveries']),list(final_data['Active cases'])):
    folium.CircleMarker(location = [lat,long],
                       radius = 5,
                       color='red',
                       fill = True,
                       fill_color="red").add_to(india1)
    folium.Marker(location = [lat,long],
              popup='<strong><b>State  : '+state+'</strong> <br>' +
                    '<strong><b>Total Cases :'+total_cases+'</striong><br>' +
                    '<strong><b>Deaths :'+Death+'</striong><br>' +
                    '<strong><b>Recoveries :'+Recov+'</striong><br>' +
                    '<strong><b>Active Cases :'+Active+'</striong>' ).add_to(india1)

# %%
india1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
india1.save('Covid_Statistics.html')
